# %% [markdown]
# # Playground

# %% [markdown]
# ## Crypto App

# %%
import streamlit as st
from PIL import Image
import pandas as pd
import base64
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests
import json
import time

# %% [markdown]
# Beautiful Soup

# %%
cmc = requests.get('https://coinmarketcap.com')
print(cmc)
print(type(cmc))
# Out:
# <Response [200]>
# <class 'requests.models.Response'>

# %%
soup = BeautifulSoup(cmc.content, 'html.parser')
print(type(soup))
# Out:
# <class 'bs4.BeautifulSoup'>

# %%
soup.title
# Out:
# <title>Cryptocurrency Prices, Charts And Market Capitalizations | CoinMarketCap</title>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <script crossorigin="anonymous">
#    (function(c,u,v,n,p,e,z,A,w){function k(a){if(!x){x=!0;var l=u.getElementsByTagName(v)[0],d=u.createElement(v);d.src=A;d.crossOrigin="anonymous";d.addEventListener("load",function(){try{c[n]=r;c[p]=t;var b=c[e],d=b.init;b.init=function(a){for(var b in a)Object.prototype.hasOwnProperty.call(a,b)&&(w[b]=a[b]);d(w)};B(a,b)}catch(g){console.error(g)}});l.parentNode.insertBefore(d,l)}}function B(a,l){try{for(var d=m.data,b=0;b<a.length;b++)if("function"===typeof a[b])a[b]();var e=!1,g=c.__SENTRY__;"undefined"!==
# typeof g&&g.hub&&g.hub.getClient()&&(e=!0);g=!1;for(b=0;b<d.length;b++)if(d[b].f){g=!0;var f=d[b];!1===e&&"init"!==f.f&&l.init();e=!0;l[f.f].apply(l,f.a)}!1===e&&!1===g&&l.init();var h=c[n],k=c[p];for(b=0;b<d.length;b++)d[b].e&&h?h.apply(c,d[b].e):d[b].p&&k&&k.apply(c,[d[b].p])}catch(C){console.error(C)}}for(var f=!0,y=!1,q=0;q<document.scripts.length;q++)if(-1<document.scripts[q].src.indexOf(z)){f="no"!==document.scripts[q].getAttribute("data-lazy");break}var x=!1,h=[],m=function(a){(a.e||a.p||a.f&&
# -1<a.f.indexOf("capture")||a.f&&-1<a.f.indexOf("showReportDialog"))&&f&&k(h);m.data.push(a)};m.data=[];c[e]=c[e]||{};c[e].onLoad=function(a){h.push(a);f&&!y||k(h)};c[e].forceLoad=function(){y=!0;f&&setTimeout(function(){k(h)})};"init addBreadcrumb captureMessage captureException captureEvent configureScope withScope showReportDialog".split(" ").forEach(function(a){c[e][a]=function(){m({f:a,a:arguments})}});var r=c[n];c[n]=function(a,e,d,b,f){m({e:[].slice.call(arguments)});r&&r.apply(c,arguments)};
# var t=c[p];c[p]=function(a){m({p:a.reason});t&&t.apply(c,arguments)};f||setTimeout(function(){k(h)})})(window,document,"script","onerror","onunhandledrejection","Sentry","c2873b0bbcab403e9bf54ffcab064d1e","https://browser.sentry-cdn.com/6.17.9/bundle.tracing.min.js",{"dsn":"https://c2873b0bbcab403e9bf54ffcab064d1e@o230231.ingest.sentry.io/1388566"});
#   </script>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, shrink-to-fit=no" name="viewport"/>
#   <script>
#    (function() {
#                 if (false) {
#                   window.__renderTime__.csrRender = 1667469987754;
#                   return;
#                 }
#                 window.__renderTime__ = {"pageInitStart":1667469987719,"pageInitEnd":1667469987735,"pageRender":1667469987754};
#                 window.__renderTime__.pageLoad = Date.now();
#               })()
#   </script>
#   <link crossorigin="anonymous" href="https://s2.coinmarketcap.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://s2.coinmarketcap.com" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://s3.coinmarketcap.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://s3.coinmarketcap.com" rel="dns-prefetch"/>
#   <link href="//www.googletagmanager.com" rel="preconnect"/>
#   <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/inter/Inter-Regular-new.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/inter/Inter-Medium-new.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/inter/Inter-SemiBold-new.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/inter/Inter-Bold-new.woff2" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/cmc-v2/CMC-V2.woff" rel="preload" type="font/woff"/>
#   <meta content="EDc1reqlQ-zAgeRrrgAxRXNK-Zs9JgpE9a0wdaoSO9A" name="google-site-verification"/>
#   <meta content="https://s2.coinmarketcap.com/static/cloud/img/splash_600x315_1.png?_=e77707c" property="og:image"/>
#   <meta content="image/png" property="og:image:type"/>
#   <meta content="600" property="og:image:width"/>
#   <meta content="315" property="og:image:height"/>
#   <meta content="CoinMarketCap" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <link href="/apple-touch-icon.png" rel="apple-touch-icon"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <meta content="https://coinmarketcap.com/" property="og:url"/>
#   <link href="https://coinmarketcap.com/" rel="canonical"/>
#   <link href="https://coinmarketcap.com/ar/" hreflang="ar" rel="alternate"/>
#   <link href="https://coinmarketcap.com/bg/" hreflang="bg" rel="alternate"/>
#   <link href="https://coinmarketcap.com/cs/" hreflang="cs" rel="alternate"/>
#   <link href="https://coinmarketcap.com/da/" hreflang="da" rel="alternate"/>
#   <link href="https://coinmarketcap.com/de/" hreflang="de" rel="alternate"/>
#   <link href="https://coinmarketcap.com/el/" hreflang="el" rel="alternate"/>
#   <link href="https://coinmarketcap.com/" hreflang="en" rel="alternate"/>
#   <link href="https://coinmarketcap.com/es/" hreflang="es" rel="alternate"/>
#   <link href="https://coinmarketcap.com/fi/" hreflang="fi" rel="alternate"/>
#   <link href="https://coinmarketcap.com/fr/" hreflang="fr" rel="alternate"/>
#   <link href="https://coinmarketcap.com/hi/" hreflang="hi" rel="alternate"/>
#   <link href="https://coinmarketcap.com/hu/" hreflang="hu" rel="alternate"/>
#   <link href="https://coinmarketcap.com/id/" hreflang="id" rel="alternate"/>
#   <link href="https://coinmarketcap.com/it/" hreflang="it" rel="alternate"/>
#   <link href="https://coinmarketcap.com/ja/" hreflang="ja" rel="alternate"/>
#   <link href="https://coinmarketcap.com/ko/" hreflang="ko" rel="alternate"/>
#   <link href="https://coinmarketcap.com/nl/" hreflang="nl" rel="alternate"/>
#   <link href="https://coinmarketcap.com/no/" hreflang="no" rel="alternate"/>
#   <link href="https://coinmarketcap.com/pl/" hreflang="pl" rel="alternate"/>
#   <link href="https://coinmarketcap.com/pt-br/" hreflang="pt-br" rel="alternate"/>
#   <link href="https://coinmarketcap.com/ro/" hreflang="ro" rel="alternate"/>
#   <link href="https://coinmarketcap.com/ru/" hreflang="ru" rel="alternate"/>
#   <link href="https://coinmarketcap.com/sk/" hreflang="sk" rel="alternate"/>
#   <link href="https://coinmarketcap.com/sv/" hreflang="sv" rel="alternate"/>
#   <link href="https://coinmarketcap.com/th/" hreflang="th" rel="alternate"/>
#   <link href="https://coinmarketcap.com/tr/" hreflang="tr" rel="alternate"/>
#   <link href="https://coinmarketcap.com/uk/" hreflang="uk" rel="alternate"/>
#   <link href="https://coinmarketcap.com/ur/" hreflang="ur" rel="alternate"/>
#   <link href="https://coinmarketcap.com/vi/" hreflang="vi" rel="alternate"/>
#   <link href="https://coinmarketcap.com/zh-tw/" hreflang="zh-tw" rel="alternate"/>
#   <link href="https://coinmarketcap.com/zh/" hreflang="zh" rel="alternate"/>
#   <link href="/manifest.json" rel="manifest"/>
#   <script charset="UTF-8">
#    var projectName="coinmarketcap.com"===location.host?"cmc":"default",sensors=window.sensorsDataAnalytic201505;!function(e){var t=e.sdk_url,r=e.name,s=window,n=document,a="script",c=null,o=null;if(void 0!==s.sensorsDataAnalytic201505)return!1;s.sensorsDataAnalytic201505=r,s[r]=s[r]||function(e){return function(){(s[r]._q=s[r]._q||[]).push([e,arguments])}};for(var i=["track","quick","register","registerPage","registerOnce","clearAllRegister","trackSignup","trackAbtest","setProfile","setOnceProfile","appendProfile","incrementProfile","deleteProfile","unsetProfile","identify","login","logout","trackLink"],l=0;l<i.length;l++)s[r][i[l]]=s[r].call(null,i[l]);s[r]._t||(c=n.createElement(a),o=n.getElementsByTagName(a)[0],c.async=1,c.src=t,c.setAttribute("charset","UTF-8"),s[r].para=e,o.parentNode.insertBefore(c,o))}({sdk_url:"https://cdn.jsdelivr.net/npm/sa-sdk-javascript@1.23.1/sensorsdata.min.js",name:"sensors",server_url:"https://sensors.saasexch.com/sa?project="+projectName,is_track_single_page:!0,use_client_time:!0,send_type:"beacon",app_js_bridge:!0,show_log:!1,heatmap:{scroll_notice_map:"scroll_notice_map",collect_tags:{div:!0}}}),sensors.quick("autoTrack");
#   </script>
#   <script charset="UTF-8">
#    var mockDidKey = 'di_kcom_gubed_resu_laer_ef';
#                 var userIndentify = localStorage.getItem(mockDidKey)
#                 if (!userIndentify) {
#                   userIndentify = Date.now() + '_' + Math.random().toString(16).substring(2);
#                   localStorage.setItem(mockDidKey, userIndentify);
#                 }
#                 var idNum = userIndentify
#                   .split('')
#                   .map((t) => +t)
#                   .filter((t) => !isNaN(t))
#                   .reduce((r, t) => r + t, 0);
#                 window.userGroup = Number(String(idNum).split('').pop());
#   </script>
#   <script>
#    window.cachedWidth = window.innerWidth
#   </script>
#   <title>
#    Cryptocurrency Prices, Charts And Market Capitalizations | CoinMarketCap
#   </title>
#   <meta content="Cryptocurrency Prices, Charts And Market Capitalizations | CoinMarketCap" property="og:title"/>
#   <meta content="Top cryptocurrency prices and charts, listed by market capitalization. Free access to current and historic data for Bitcoin and thousands of altcoins." name="description"/>
#   <meta content="Top cryptocurrency prices and charts, listed by market capitalization. Free access to current and historic data for Bitcoin and thousands of altcoins." property="og:description"/>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"Organization","name":"CoinMarketCap","url":"https://coinmarketcap.com","logo":"https://coinmarketcap.com/apple-touch-icon.png","sameAs":["https://www.facebook.com/CoinMarketCap/","https://twitter.com/coinmarketcap"]}
#   </script>
#   <script type="application/ld+json">
#    {"@context":"http://schema.org","@type":"Table","about":"Cryptocurrency Prices Today"}
#   </script>
#   <meta content="67" name="next-head-count"/>
#   <link as="style" href="https://s2.coinmarketcap.com/_next/static/css/e3e2a5c7a36a93d0.css" rel="preload"/>
#   <link data-n-g="" href="https://s2.coinmarketcap.com/_next/static/css/e3e2a5c7a36a93d0.css" rel="stylesheet"/>
#   <noscript data-n-css="">
#   </noscript>
#   <script defer="" nomodule="" src="https://s2.coinmarketcap.com/_next/static/chunks/polyfills-5cd94c89d3acac5f.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/7215.8611db9b31a2686e.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/8901.a148f74f44975b8e.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/webpack-ad022829fc77c0c1.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/framework-b47f23e1edf87104.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/main-0fe54bb3f30e8d6b.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/pages/_app-160d0c588c04dc1a.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/commons-cfbad8d95e26032e.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/1657-84dd17d07a08aaae.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/1509-c1314e6188acd82a.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/7050-8ccbaa9dba72968e.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/4711-4e76954db0952fcb.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/4069-b30d17e1dd2d9865.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/9264-94909d7e4257e5f9.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/1246-0680118f8fb26a85.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/2740-7a371f84021c6b56.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/4769-5379c59b128cc32f.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/6701-cec75b0da2f12784.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/7490-8f073ebf730e446f.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/8695-6a23452cb15bcc32.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/9352-7054c951d6211fb1.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/8037-37ea4e42c0725cf9.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/1114-eebe8c267572baf9.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/1913-d36524cefa2449d3.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/9068-59c61190a9caa219.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/8867-e95edd7f7bdd49cf.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/951-5e5506a6def197c0.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/9337-5239d3fd6cc73322.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/9205-6208aeba9616766b.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/1884-139d30ea70732141.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/3182-e1434cbe26c7cf1a.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/7787-b66db4a52e54aa57.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/216-601ab46a8c761225.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/chunks/pages/index-0cf6ccc464bab672.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/e77707c5/_buildManifest.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/e77707c5/_ssgManifest.js">
#   </script>
#   <script defer="" src="https://s2.coinmarketcap.com/_next/static/e77707c5/_middlewareManifest.js">
#   </script>
#   <style data-styled="" data-styled-version="5.1.1">
#    .drWdNN{box-sizing:border-box;margin:0;height:40;width:40;}/*!sc*/
# .drWdNN a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .eFjnQR{box-sizing:border-box;margin:0;height:24px;width:24px;}/*!sc*/
# .eFjnQR a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fFoBIX{box-sizing:border-box;margin:0;padding-top:4px;padding-bottom:16px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# .fFoBIX a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media screen and (min-width:768px){.fFoBIX{padding-top:24px;padding-bottom:24px;}}/*!sc*/
# @media screen and (min-width:768px){}/*!sc*/
# @media screen and (min-width:1152px){.fFoBIX{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}}/*!sc*/
# .hiljBt{box-sizing:border-box;margin:0;margin-right:0;-webkit-flex:1;-ms-flex:1;flex:1;}/*!sc*/
# .hiljBt a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media screen and (min-width:768px){.hiljBt{margin-right:0;}}/*!sc*/
# @media screen and (min-width:1152px){.hiljBt{margin-right:24px;}}/*!sc*/
# .cyZVgY{box-sizing:border-box;margin:0;}/*!sc*/
# .cyZVgY a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hGDrMm{box-sizing:border-box;margin:0;margin-right:4px;}/*!sc*/
# .hGDrMm a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .drZeym{box-sizing:border-box;margin:0;margin-top:16px;}/*!sc*/
# .drZeym a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fzviVH{box-sizing:border-box;margin:0;height:8;width:6;}/*!sc*/
# .fzviVH a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .PzkeQ{box-sizing:border-box;margin:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .PzkeQ a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gDAmrQ{box-sizing:border-box;margin:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# .gDAmrQ a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .iJXSkb{box-sizing:border-box;margin:0;width:100%;}/*!sc*/
# .iJXSkb a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dEHpSU{box-sizing:border-box;margin:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# .dEHpSU a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hgJtSJ{box-sizing:border-box;margin:0;height:14px;width:14px;}/*!sc*/
# .hgJtSJ a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fpZGGP{box-sizing:border-box;margin:0;height:16;width:16;color:#A6B0C3;}/*!sc*/
# .fpZGGP a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .kLinMv{box-sizing:border-box;margin:0;background-color:#F8FAFD;}/*!sc*/
# .kLinMv a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .fIjNMv{box-sizing:border-box;margin:0;padding-left:16px;padding-right:16px;margin-left:auto;margin-right:auto;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:start;-webkit-justify-content:flex-start;-ms-flex-pack:start;justify-content:flex-start;}/*!sc*/
# .fIjNMv a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media screen and (min-width:768px){.fIjNMv{padding-left:24px;padding-right:0;}}/*!sc*/
# @media screen and (min-width:1152px){.fIjNMv{padding-right:24px;}}/*!sc*/
# @media screen and (min-width:768px){.fIjNMv{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;}}/*!sc*/
# .gRKkUT{box-sizing:border-box;margin:0;}/*!sc*/
# .gRKkUT a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media screen and (min-width:768px){.gRKkUT{-webkit-flex:70%;-ms-flex:70%;flex:70%;}}/*!sc*/
# @media screen and (min-width:1152px){.gRKkUT{-webkit-flex:60%;-ms-flex:60%;flex:60%;}}/*!sc*/
# .eyImcC{box-sizing:border-box;margin:0;display:block;}/*!sc*/
# .eyImcC a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media screen and (min-width:768px){}/*!sc*/
# @media screen and (min-width:1152px){.eyImcC{display:inline;}}/*!sc*/
# .etZTIR{box-sizing:border-box;margin:0;margin-bottom:32px;display:block;}/*!sc*/
# .etZTIR a:-webkit-any-link{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# @media screen and (min-width:768px){.etZTIR{margin-bottom:64px;}}/*!sc*/
# @media screen and (min-width:1152px){.etZTIR{margin-bottom:128px;}}/*!sc*/
# @media screen and (min-width:768px){.etZTIR{display:inline-block;}}/*!sc*/
# data-styled.g5[id="sc-1prm8qw-0"]{content:"drWdNN,eFjnQR,fFoBIX,hiljBt,cyZVgY,hGDrMm,drZeym,fzviVH,PzkeQ,gDAmrQ,iJXSkb,dEHpSU,hgJtSJ,fpZGGP,kLinMv,fIjNMv,gRKkUT,eyImcC,etZTIR,"}/*!sc*/
# .cLXodu .grid{box-sizing:border-box;width:100%;padding-right:16px;padding-left:16px;margin-right:auto;margin-left:auto;}/*!sc*/
# @media (min-width:1376px){.cLXodu .grid{max-width:1408px;}}/*!sc*/
# .cLXodu .grid.edge-md{padding-right:0;padding-left:0;}/*!sc*/
# @media (min-width:1152px){.cLXodu .grid.edge-md{padding-right:16px;padding-left:16px;}}/*!sc*/
# .cLXodu .grid-fluid,.cLXodu .grid-xl{width:100%;padding-right:16px;padding-left:16px;margin-right:auto;margin-left:auto;}/*!sc*/
# @media (min-width:1376px){.cLXodu .grid,.cLXodu .grid-sm,.cLXodu .grid-md,.cLXodu .grid-lg,.cLXodu .grid-xl{max-width:1408px;}}/*!sc*/
# .cLXodu .uikit-row{box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;margin-right:-16px;margin-left:-16px;}/*!sc*/
# .cLXodu .no-gutters{margin-right:0;margin-left:0;}/*!sc*/
# .cLXodu .no-gutters > .uikit-col,.cLXodu .no-gutters > [class*='uikit-col-']{padding-right:0;padding-left:0;}/*!sc*/
# .cLXodu .uikit-col-1,.cLXodu .uikit-col-2,.cLXodu .uikit-col-3,.cLXodu .uikit-col-4,.cLXodu .uikit-col-5,.cLXodu .uikit-col-6,.cLXodu .uikit-col-7,.cLXodu .uikit-col-8,.cLXodu .uikit-col-9,.cLXodu .uikit-col-10,.cLXodu .uikit-col-11,.cLXodu .uikit-col-12,.cLXodu .uikit-col-13,.cLXodu .uikit-col-14,.cLXodu .uikit-col-15,.cLXodu .uikit-col-16,.cLXodu .uikit-col,.cLXodu .uikit-col-auto,.cLXodu .uikit-col-sm-1,.cLXodu .uikit-col-sm-2,.cLXodu .uikit-col-sm-3,.cLXodu .uikit-col-sm-4,.cLXodu .uikit-col-sm-5,.cLXodu .uikit-col-sm-6,.cLXodu .uikit-col-sm-7,.cLXodu .uikit-col-sm-8,.cLXodu .uikit-col-sm-9,.cLXodu .uikit-col-sm-10,.cLXodu .uikit-col-sm-11,.cLXodu .uikit-col-sm-12,.cLXodu .uikit-col-sm-13,.cLXodu .uikit-col-sm-14,.cLXodu .uikit-col-sm-15,.cLXodu .uikit-col-sm-16,.cLXodu .uikit-col-sm,.cLXodu .uikit-col-sm-auto,.cLXodu .uikit-col-md-1,.cLXodu .uikit-col-md-2,.cLXodu .uikit-col-md-3,.cLXodu .uikit-col-md-4,.cLXodu .uikit-col-md-5,.cLXodu .uikit-col-md-6,.cLXodu .uikit-col-md-7,.cLXodu .uikit-col-md-8,.cLXodu .uikit-col-md-9,.cLXodu .uikit-col-md-10,.cLXodu .uikit-col-md-11,.cLXodu .uikit-col-md-12,.cLXodu .uikit-col-md-13,.cLXodu .uikit-col-md-14,.cLXodu .uikit-col-md-15,.cLXodu .uikit-col-md-16,.cLXodu .uikit-col-md,.cLXodu .uikit-col-md-auto,.cLXodu .uikit-col-lg-1,.cLXodu .uikit-col-lg-2,.cLXodu .uikit-col-lg-3,.cLXodu .uikit-col-lg-4,.cLXodu .uikit-col-lg-5,.cLXodu .uikit-col-lg-6,.cLXodu .uikit-col-lg-7,.cLXodu .uikit-col-lg-8,.cLXodu .uikit-col-lg-9,.cLXodu .uikit-col-lg-10,.cLXodu .uikit-col-lg-11,.cLXodu .uikit-col-lg-12,.cLXodu .uikit-col-lg-13,.cLXodu .uikit-col-lg-14,.cLXodu .uikit-col-lg-15,.cLXodu .uikit-col-lg-16,.cLXodu .uikit-col-lg,.cLXodu .uikit-col-lg-auto,.cLXodu .uikit-col-xl-1,.cLXodu .uikit-col-xl-2,.cLXodu .uikit-col-xl-3,.cLXodu .uikit-col-xl-4,.cLXodu .uikit-col-xl-5,.cLXodu .uikit-col-xl-6,.cLXodu .uikit-col-xl-7,.cLXodu .uikit-col-xl-8,.cLXodu .uikit-col-xl-9,.cLXodu .uikit-col-xl-10,.cLXodu .uikit-col-xl-11,.cLXodu .uikit-col-xl-12,.cLXodu .uikit-col-xl-13,.cLXodu .uikit-col-xl-14,.cLXodu .uikit-col-xl-15,.cLXodu .uikit-col-xl-16,.cLXodu .uikit-col-xl,.cLXodu .uikit-col-xl-auto{box-sizing:border-box;position:relative;width:100%;padding-right:16px;padding-left:16px;}/*!sc*/
# .cLXodu .uikit-col{-webkit-flex-basis:0;-ms-flex-preferred-size:0;flex-basis:0;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;min-width:0;max-width:100%;}/*!sc*/
# .cLXodu .uikit-row-cols-1 > *{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}/*!sc*/
# .cLXodu .uikit-row-cols-2 > *{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}/*!sc*/
# .cLXodu .uikit-row-cols-3 > *{-webkit-flex:0 0 33.33333%;-ms-flex:0 0 33.33333%;flex:0 0 33.33333%;max-width:33.33333%;}/*!sc*/
# .cLXodu .uikit-row-cols-4 > *{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}/*!sc*/
# .cLXodu .uikit-row-cols-5 > *{-webkit-flex:0 0 20%;-ms-flex:0 0 20%;flex:0 0 20%;max-width:20%;}/*!sc*/
# .cLXodu .uikit-row-cols-6 > *{-webkit-flex:0 0 16.66667%;-ms-flex:0 0 16.66667%;flex:0 0 16.66667%;max-width:16.66667%;}/*!sc*/
# .cLXodu .uikit-col-auto{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;width:auto;max-width:100%;}/*!sc*/
# .cLXodu .uikit-col-1{-webkit-flex:0 0 6.25%;-ms-flex:0 0 6.25%;flex:0 0 6.25%;max-width:6.25%;}/*!sc*/
# .cLXodu .uikit-col-2{-webkit-flex:0 0 12.5%;-ms-flex:0 0 12.5%;flex:0 0 12.5%;max-width:12.5%;}/*!sc*/
# .cLXodu .uikit-col-3{-webkit-flex:0 0 18.75%;-ms-flex:0 0 18.75%;flex:0 0 18.75%;max-width:18.75%;}/*!sc*/
# .cLXodu .uikit-col-4{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}/*!sc*/
# .cLXodu .uikit-col-5{-webkit-flex:0 0 31.25%;-ms-flex:0 0 31.25%;flex:0 0 31.25%;max-width:31.25%;}/*!sc*/
# .cLXodu .uikit-col-6{-webkit-flex:0 0 37.5%;-ms-flex:0 0 37.5%;flex:0 0 37.5%;max-width:37.5%;}/*!sc*/
# .cLXodu .uikit-col-7{-webkit-flex:0 0 43.75%;-ms-flex:0 0 43.75%;flex:0 0 43.75%;max-width:43.75%;}/*!sc*/
# .cLXodu .uikit-col-8{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}/*!sc*/
# .cLXodu .uikit-col-9{-webkit-flex:0 0 56.25%;-ms-flex:0 0 56.25%;flex:0 0 56.25%;max-width:56.25%;}/*!sc*/
# .cLXodu .uikit-col-10{-webkit-flex:0 0 62.5%;-ms-flex:0 0 62.5%;flex:0 0 62.5%;max-width:62.5%;}/*!sc*/
# .cLXodu .uikit-col-11{-webkit-flex:0 0 68.75%;-ms-flex:0 0 68.75%;flex:0 0 68.75%;max-width:68.75%;}/*!sc*/
# .cLXodu .uikit-col-12{-webkit-flex:0 0 75%;-ms-flex:0 0 75%;flex:0 0 75%;max-width:75%;}/*!sc*/
# .cLXodu .uikit-col-13{-webkit-flex:0 0 81.25%;-ms-flex:0 0 81.25%;flex:0 0 81.25%;max-width:81.25%;}/*!sc*/
# .cLXodu .uikit-col-14{-webkit-flex:0 0 87.5%;-ms-flex:0 0 87.5%;flex:0 0 87.5%;max-width:87.5%;}/*!sc*/
# .cLXodu .uikit-col-15{-webkit-flex:0 0 93.75%;-ms-flex:0 0 93.75%;flex:0 0 93.75%;max-width:93.75%;}/*!sc*/
# .cLXodu .uikit-col-16{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}/*!sc*/
# .cLXodu .uikit-order-first{-webkit-order:-1;-ms-flex-order:-1;order:-1;}/*!sc*/
# .cLXodu .uikit-order-last{-webkit-order:17;-ms-flex-order:17;order:17;}/*!sc*/
# .cLXodu .uikit-order-0{-webkit-order:0;-ms-flex-order:0;order:0;}/*!sc*/
# .cLXodu .uikit-order-1{-webkit-order:1;-ms-flex-order:1;order:1;}/*!sc*/
# .cLXodu .uikit-order-2{-webkit-order:2;-ms-flex-order:2;order:2;}/*!sc*/
# .cLXodu .uikit-order-3{-webkit-order:3;-ms-flex-order:3;order:3;}/*!sc*/
# .cLXodu .uikit-order-4{-webkit-order:4;-ms-flex-order:4;order:4;}/*!sc*/
# .cLXodu .uikit-order-5{-webkit-order:5;-ms-flex-order:5;order:5;}/*!sc*/
# .cLXodu .uikit-order-6{-webkit-order:6;-ms-flex-order:6;order:6;}/*!sc*/
# .cLXodu .uikit-order-7{-webkit-order:7;-ms-flex-order:7;order:7;}/*!sc*/
# .cLXodu .uikit-order-8{-webkit-order:8;-ms-flex-order:8;order:8;}/*!sc*/
# .cLXodu .uikit-order-9{-webkit-order:9;-ms-flex-order:9;order:9;}/*!sc*/
# .cLXodu .uikit-order-10{-webkit-order:10;-ms-flex-order:10;order:10;}/*!sc*/
# .cLXodu .uikit-order-11{-webkit-order:11;-ms-flex-order:11;order:11;}/*!sc*/
# .cLXodu .uikit-order-12{-webkit-order:12;-ms-flex-order:12;order:12;}/*!sc*/
# .cLXodu .uikit-order-13{-webkit-order:13;-ms-flex-order:13;order:13;}/*!sc*/
# .cLXodu .uikit-order-14{-webkit-order:14;-ms-flex-order:14;order:14;}/*!sc*/
# .cLXodu .uikit-order-15{-webkit-order:15;-ms-flex-order:15;order:15;}/*!sc*/
# .cLXodu .uikit-order-16{-webkit-order:16;-ms-flex-order:16;order:16;}/*!sc*/
# .cLXodu .uikit-offset-1{margin-left:6.25%;}/*!sc*/
# .cLXodu .uikit-offset-2{margin-left:12.5%;}/*!sc*/
# .cLXodu .uikit-offset-3{margin-left:18.75%;}/*!sc*/
# .cLXodu .uikit-offset-4{margin-left:25%;}/*!sc*/
# .cLXodu .uikit-offset-5{margin-left:31.25%;}/*!sc*/
# .cLXodu .uikit-offset-6{margin-left:37.5%;}/*!sc*/
# .cLXodu .uikit-offset-7{margin-left:43.75%;}/*!sc*/
# .cLXodu .uikit-offset-8{margin-left:50%;}/*!sc*/
# .cLXodu .uikit-offset-9{margin-left:56.25%;}/*!sc*/
# .cLXodu .uikit-offset-10{margin-left:62.5%;}/*!sc*/
# .cLXodu .uikit-offset-11{margin-left:68.75%;}/*!sc*/
# .cLXodu .uikit-offset-12{margin-left:75%;}/*!sc*/
# .cLXodu .uikit-offset-13{margin-left:81.25%;}/*!sc*/
# .cLXodu .uikit-offset-14{margin-left:87.5%;}/*!sc*/
# .cLXodu .uikit-offset-15{margin-left:93.75%;}/*!sc*/
# @media (min-width:768px){.cLXodu .uikit-col-sm{-webkit-flex-basis:0;-ms-flex-preferred-size:0;flex-basis:0;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;min-width:0;max-width:100%;}.cLXodu .uikit-row-cols-sm-1 > *{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}.cLXodu .uikit-row-cols-sm-2 > *{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}.cLXodu .uikit-row-cols-sm-3 > *{-webkit-flex:0 0 33.33333%;-ms-flex:0 0 33.33333%;flex:0 0 33.33333%;max-width:33.33333%;}.cLXodu .uikit-row-cols-sm-4 > *{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}.cLXodu .uikit-row-cols-sm-5 > *{-webkit-flex:0 0 20%;-ms-flex:0 0 20%;flex:0 0 20%;max-width:20%;}.cLXodu .uikit-row-cols-sm-6 > *{-webkit-flex:0 0 16.66667%;-ms-flex:0 0 16.66667%;flex:0 0 16.66667%;max-width:16.66667%;}.cLXodu .uikit-col-sm-auto{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;width:auto;max-width:100%;}.cLXodu .uikit-col-sm-1{-webkit-flex:0 0 6.25%;-ms-flex:0 0 6.25%;flex:0 0 6.25%;max-width:6.25%;}.cLXodu .uikit-col-sm-2{-webkit-flex:0 0 12.5%;-ms-flex:0 0 12.5%;flex:0 0 12.5%;max-width:12.5%;}.cLXodu .uikit-col-sm-3{-webkit-flex:0 0 18.75%;-ms-flex:0 0 18.75%;flex:0 0 18.75%;max-width:18.75%;}.cLXodu .uikit-col-sm-4{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}.cLXodu .uikit-col-sm-5{-webkit-flex:0 0 31.25%;-ms-flex:0 0 31.25%;flex:0 0 31.25%;max-width:31.25%;}.cLXodu .uikit-col-sm-6{-webkit-flex:0 0 37.5%;-ms-flex:0 0 37.5%;flex:0 0 37.5%;max-width:37.5%;}.cLXodu .uikit-col-sm-7{-webkit-flex:0 0 43.75%;-ms-flex:0 0 43.75%;flex:0 0 43.75%;max-width:43.75%;}.cLXodu .uikit-col-sm-8{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}.cLXodu .uikit-col-sm-9{-webkit-flex:0 0 56.25%;-ms-flex:0 0 56.25%;flex:0 0 56.25%;max-width:56.25%;}.cLXodu .uikit-col-sm-10{-webkit-flex:0 0 62.5%;-ms-flex:0 0 62.5%;flex:0 0 62.5%;max-width:62.5%;}.cLXodu .uikit-col-sm-11{-webkit-flex:0 0 68.75%;-ms-flex:0 0 68.75%;flex:0 0 68.75%;max-width:68.75%;}.cLXodu .uikit-col-sm-12{-webkit-flex:0 0 75%;-ms-flex:0 0 75%;flex:0 0 75%;max-width:75%;}.cLXodu .uikit-col-sm-13{-webkit-flex:0 0 81.25%;-ms-flex:0 0 81.25%;flex:0 0 81.25%;max-width:81.25%;}.cLXodu .uikit-col-sm-14{-webkit-flex:0 0 87.5%;-ms-flex:0 0 87.5%;flex:0 0 87.5%;max-width:87.5%;}.cLXodu .uikit-col-sm-15{-webkit-flex:0 0 93.75%;-ms-flex:0 0 93.75%;flex:0 0 93.75%;max-width:93.75%;}.cLXodu .uikit-col-sm-16{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}.cLXodu .uikit-order-sm-first{-webkit-order:-1;-ms-flex-order:-1;order:-1;}.cLXodu .uikit-order-sm-last{-webkit-order:17;-ms-flex-order:17;order:17;}.cLXodu .uikit-order-sm-0{-webkit-order:0;-ms-flex-order:0;order:0;}.cLXodu .uikit-order-sm-1{-webkit-order:1;-ms-flex-order:1;order:1;}.cLXodu .uikit-order-sm-2{-webkit-order:2;-ms-flex-order:2;order:2;}.cLXodu .uikit-order-sm-3{-webkit-order:3;-ms-flex-order:3;order:3;}.cLXodu .uikit-order-sm-4{-webkit-order:4;-ms-flex-order:4;order:4;}.cLXodu .uikit-order-sm-5{-webkit-order:5;-ms-flex-order:5;order:5;}.cLXodu .uikit-order-sm-6{-webkit-order:6;-ms-flex-order:6;order:6;}.cLXodu .uikit-order-sm-7{-webkit-order:7;-ms-flex-order:7;order:7;}.cLXodu .uikit-order-sm-8{-webkit-order:8;-ms-flex-order:8;order:8;}.cLXodu .uikit-order-sm-9{-webkit-order:9;-ms-flex-order:9;order:9;}.cLXodu .uikit-order-sm-10{-webkit-order:10;-ms-flex-order:10;order:10;}.cLXodu .uikit-order-sm-11{-webkit-order:11;-ms-flex-order:11;order:11;}.cLXodu .uikit-order-sm-12{-webkit-order:12;-ms-flex-order:12;order:12;}.cLXodu .uikit-order-sm-13{-webkit-order:13;-ms-flex-order:13;order:13;}.cLXodu .uikit-order-sm-14{-webkit-order:14;-ms-flex-order:14;order:14;}.cLXodu .uikit-order-sm-15{-webkit-order:15;-ms-flex-order:15;order:15;}.cLXodu .uikit-order-sm-16{-webkit-order:16;-ms-flex-order:16;order:16;}.cLXodu .uikit-offset-sm-0{margin-left:0;}.cLXodu .uikit-offset-sm-1{margin-left:6.25%;}.cLXodu .uikit-offset-sm-2{margin-left:12.5% ...
# @media (min-width:1152px){.cLXodu .uikit-col-md{-webkit-flex-basis:0;-ms-flex-preferred-size:0;flex-basis:0;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;min-width:0;max-width:100%;}.cLXodu .uikit-row-cols-md-1 > *{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}.cLXodu .uikit-row-cols-md-2 > *{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}.cLXodu .uikit-row-cols-md-3 > *{-webkit-flex:0 0 33.33333%;-ms-flex:0 0 33.33333%;flex:0 0 33.33333%;max-width:33.33333%;}.cLXodu .uikit-row-cols-md-4 > *{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}.cLXodu .uikit-row-cols-md-5 > *{-webkit-flex:0 0 20%;-ms-flex:0 0 20%;flex:0 0 20%;max-width:20%;}.cLXodu .uikit-row-cols-md-6 > *{-webkit-flex:0 0 16.66667%;-ms-flex:0 0 16.66667%;flex:0 0 16.66667%;max-width:16.66667%;}.cLXodu .uikit-col-md-auto{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;width:auto;max-width:100%;}.cLXodu .uikit-col-md-1{-webkit-flex:0 0 6.25%;-ms-flex:0 0 6.25%;flex:0 0 6.25%;max-width:6.25%;}.cLXodu .uikit-col-md-2{-webkit-flex:0 0 12.5%;-ms-flex:0 0 12.5%;flex:0 0 12.5%;max-width:12.5%;}.cLXodu .uikit-col-md-3{-webkit-flex:0 0 18.75%;-ms-flex:0 0 18.75%;flex:0 0 18.75%;max-width:18.75%;}.cLXodu .uikit-col-md-4{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}.cLXodu .uikit-col-md-5{-webkit-flex:0 0 31.25%;-ms-flex:0 0 31.25%;flex:0 0 31.25%;max-width:31.25%;}.cLXodu .uikit-col-md-6{-webkit-flex:0 0 37.5%;-ms-flex:0 0 37.5%;flex:0 0 37.5%;max-width:37.5%;}.cLXodu .uikit-col-md-7{-webkit-flex:0 0 43.75%;-ms-flex:0 0 43.75%;flex:0 0 43.75%;max-width:43.75%;}.cLXodu .uikit-col-md-8{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}.cLXodu .uikit-col-md-9{-webkit-flex:0 0 56.25%;-ms-flex:0 0 56.25%;flex:0 0 56.25%;max-width:56.25%;}.cLXodu .uikit-col-md-10{-webkit-flex:0 0 62.5%;-ms-flex:0 0 62.5%;flex:0 0 62.5%;max-width:62.5%;}.cLXodu .uikit-col-md-11{-webkit-flex:0 0 68.75%;-ms-flex:0 0 68.75%;flex:0 0 68.75%;max-width:68.75%;}.cLXodu .uikit-col-md-12{-webkit-flex:0 0 75%;-ms-flex:0 0 75%;flex:0 0 75%;max-width:75%;}.cLXodu .uikit-col-md-13{-webkit-flex:0 0 81.25%;-ms-flex:0 0 81.25%;flex:0 0 81.25%;max-width:81.25%;}.cLXodu .uikit-col-md-14{-webkit-flex:0 0 87.5%;-ms-flex:0 0 87.5%;flex:0 0 87.5%;max-width:87.5%;}.cLXodu .uikit-col-md-15{-webkit-flex:0 0 93.75%;-ms-flex:0 0 93.75%;flex:0 0 93.75%;max-width:93.75%;}.cLXodu .uikit-col-md-16{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}.cLXodu .uikit-order-md-first{-webkit-order:-1;-ms-flex-order:-1;order:-1;}.cLXodu .uikit-order-md-last{-webkit-order:17;-ms-flex-order:17;order:17;}.cLXodu .uikit-order-md-0{-webkit-order:0;-ms-flex-order:0;order:0;}.cLXodu .uikit-order-md-1{-webkit-order:1;-ms-flex-order:1;order:1;}.cLXodu .uikit-order-md-2{-webkit-order:2;-ms-flex-order:2;order:2;}.cLXodu .uikit-order-md-3{-webkit-order:3;-ms-flex-order:3;order:3;}.cLXodu .uikit-order-md-4{-webkit-order:4;-ms-flex-order:4;order:4;}.cLXodu .uikit-order-md-5{-webkit-order:5;-ms-flex-order:5;order:5;}.cLXodu .uikit-order-md-6{-webkit-order:6;-ms-flex-order:6;order:6;}.cLXodu .uikit-order-md-7{-webkit-order:7;-ms-flex-order:7;order:7;}.cLXodu .uikit-order-md-8{-webkit-order:8;-ms-flex-order:8;order:8;}.cLXodu .uikit-order-md-9{-webkit-order:9;-ms-flex-order:9;order:9;}.cLXodu .uikit-order-md-10{-webkit-order:10;-ms-flex-order:10;order:10;}.cLXodu .uikit-order-md-11{-webkit-order:11;-ms-flex-order:11;order:11;}.cLXodu .uikit-order-md-12{-webkit-order:12;-ms-flex-order:12;order:12;}.cLXodu .uikit-order-md-13{-webkit-order:13;-ms-flex-order:13;order:13;}.cLXodu .uikit-order-md-14{-webkit-order:14;-ms-flex-order:14;order:14;}.cLXodu .uikit-order-md-15{-webkit-order:15;-ms-flex-order:15;order:15;}.cLXodu .uikit-order-md-16{-webkit-order:16;-ms-flex-order:16;order:16;}.cLXodu .uikit-offset-md-0{margin-left:0;}.cLXodu .uikit-offset-md-1{margin-left:6.25%;}.cLXodu .uikit-offset-md-2{margin-left:12.5 ...
# @media (min-width:1248px){.cLXodu .uikit-col-lg{-webkit-flex-basis:0;-ms-flex-preferred-size:0;flex-basis:0;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;min-width:0;max-width:100%;}.cLXodu .uikit-row-cols-lg-1 > *{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}.cLXodu .uikit-row-cols-lg-2 > *{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}.cLXodu .uikit-row-cols-lg-3 > *{-webkit-flex:0 0 33.33333%;-ms-flex:0 0 33.33333%;flex:0 0 33.33333%;max-width:33.33333%;}.cLXodu .uikit-row-cols-lg-4 > *{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}.cLXodu .uikit-row-cols-lg-5 > *{-webkit-flex:0 0 20%;-ms-flex:0 0 20%;flex:0 0 20%;max-width:20%;}.cLXodu .uikit-row-cols-lg-6 > *{-webkit-flex:0 0 16.66667%;-ms-flex:0 0 16.66667%;flex:0 0 16.66667%;max-width:16.66667%;}.cLXodu .uikit-col-lg-auto{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;width:auto;max-width:100%;}.cLXodu .uikit-col-lg-1{-webkit-flex:0 0 6.25%;-ms-flex:0 0 6.25%;flex:0 0 6.25%;max-width:6.25%;}.cLXodu .uikit-col-lg-2{-webkit-flex:0 0 12.5%;-ms-flex:0 0 12.5%;flex:0 0 12.5%;max-width:12.5%;}.cLXodu .uikit-col-lg-3{-webkit-flex:0 0 18.75%;-ms-flex:0 0 18.75%;flex:0 0 18.75%;max-width:18.75%;}.cLXodu .uikit-col-lg-4{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}.cLXodu .uikit-col-lg-5{-webkit-flex:0 0 31.25%;-ms-flex:0 0 31.25%;flex:0 0 31.25%;max-width:31.25%;}.cLXodu .uikit-col-lg-6{-webkit-flex:0 0 37.5%;-ms-flex:0 0 37.5%;flex:0 0 37.5%;max-width:37.5%;}.cLXodu .uikit-col-lg-7{-webkit-flex:0 0 43.75%;-ms-flex:0 0 43.75%;flex:0 0 43.75%;max-width:43.75%;}.cLXodu .uikit-col-lg-8{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}.cLXodu .uikit-col-lg-9{-webkit-flex:0 0 56.25%;-ms-flex:0 0 56.25%;flex:0 0 56.25%;max-width:56.25%;}.cLXodu .uikit-col-lg-10{-webkit-flex:0 0 62.5%;-ms-flex:0 0 62.5%;flex:0 0 62.5%;max-width:62.5%;}.cLXodu .uikit-col-lg-11{-webkit-flex:0 0 68.75%;-ms-flex:0 0 68.75%;flex:0 0 68.75%;max-width:68.75%;}.cLXodu .uikit-col-lg-12{-webkit-flex:0 0 75%;-ms-flex:0 0 75%;flex:0 0 75%;max-width:75%;}.cLXodu .uikit-col-lg-13{-webkit-flex:0 0 81.25%;-ms-flex:0 0 81.25%;flex:0 0 81.25%;max-width:81.25%;}.cLXodu .uikit-col-lg-14{-webkit-flex:0 0 87.5%;-ms-flex:0 0 87.5%;flex:0 0 87.5%;max-width:87.5%;}.cLXodu .uikit-col-lg-15{-webkit-flex:0 0 93.75%;-ms-flex:0 0 93.75%;flex:0 0 93.75%;max-width:93.75%;}.cLXodu .uikit-col-lg-16{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}.cLXodu .uikit-order-lg-first{-webkit-order:-1;-ms-flex-order:-1;order:-1;}.cLXodu .uikit-order-lg-last{-webkit-order:17;-ms-flex-order:17;order:17;}.cLXodu .uikit-order-lg-0{-webkit-order:0;-ms-flex-order:0;order:0;}.cLXodu .uikit-order-lg-1{-webkit-order:1;-ms-flex-order:1;order:1;}.cLXodu .uikit-order-lg-2{-webkit-order:2;-ms-flex-order:2;order:2;}.cLXodu .uikit-order-lg-3{-webkit-order:3;-ms-flex-order:3;order:3;}.cLXodu .uikit-order-lg-4{-webkit-order:4;-ms-flex-order:4;order:4;}.cLXodu .uikit-order-lg-5{-webkit-order:5;-ms-flex-order:5;order:5;}.cLXodu .uikit-order-lg-6{-webkit-order:6;-ms-flex-order:6;order:6;}.cLXodu .uikit-order-lg-7{-webkit-order:7;-ms-flex-order:7;order:7;}.cLXodu .uikit-order-lg-8{-webkit-order:8;-ms-flex-order:8;order:8;}.cLXodu .uikit-order-lg-9{-webkit-order:9;-ms-flex-order:9;order:9;}.cLXodu .uikit-order-lg-10{-webkit-order:10;-ms-flex-order:10;order:10;}.cLXodu .uikit-order-lg-11{-webkit-order:11;-ms-flex-order:11;order:11;}.cLXodu .uikit-order-lg-12{-webkit-order:12;-ms-flex-order:12;order:12;}.cLXodu .uikit-order-lg-13{-webkit-order:13;-ms-flex-order:13;order:13;}.cLXodu .uikit-order-lg-14{-webkit-order:14;-ms-flex-order:14;order:14;}.cLXodu .uikit-order-lg-15{-webkit-order:15;-ms-flex-order:15;order:15;}.cLXodu .uikit-order-lg-16{-webkit-order:16;-ms-flex-order:16;order:16;}.cLXodu .uikit-offset-lg-0{margin-left:0;}.cLXodu .uikit-offset-lg-1{margin-left:6.25%;}.cLXodu .uikit-offset-lg-2{margin-left:12.5 ...
# @media (min-width:1376px){.cLXodu .uikit-col-xl{-webkit-flex-basis:0;-ms-flex-preferred-size:0;flex-basis:0;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;min-width:0;max-width:100%;}.cLXodu .uikit-row-cols-xl-1 > *{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}.cLXodu .uikit-row-cols-xl-2 > *{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}.cLXodu .uikit-row-cols-xl-3 > *{-webkit-flex:0 0 33.33333%;-ms-flex:0 0 33.33333%;flex:0 0 33.33333%;max-width:33.33333%;}.cLXodu .uikit-row-cols-xl-4 > *{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}.cLXodu .uikit-row-cols-xl-5 > *{-webkit-flex:0 0 20%;-ms-flex:0 0 20%;flex:0 0 20%;max-width:20%;}.cLXodu .uikit-row-cols-xl-6 > *{-webkit-flex:0 0 16.66667%;-ms-flex:0 0 16.66667%;flex:0 0 16.66667%;max-width:16.66667%;}.cLXodu .uikit-col-xl-auto{-webkit-flex:0 0 auto;-ms-flex:0 0 auto;flex:0 0 auto;width:auto;max-width:100%;}.cLXodu .uikit-col-xl-1{-webkit-flex:0 0 6.25%;-ms-flex:0 0 6.25%;flex:0 0 6.25%;max-width:6.25%;}.cLXodu .uikit-col-xl-2{-webkit-flex:0 0 12.5%;-ms-flex:0 0 12.5%;flex:0 0 12.5%;max-width:12.5%;}.cLXodu .uikit-col-xl-3{-webkit-flex:0 0 18.75%;-ms-flex:0 0 18.75%;flex:0 0 18.75%;max-width:18.75%;}.cLXodu .uikit-col-xl-4{-webkit-flex:0 0 25%;-ms-flex:0 0 25%;flex:0 0 25%;max-width:25%;}.cLXodu .uikit-col-xl-5{-webkit-flex:0 0 31.25%;-ms-flex:0 0 31.25%;flex:0 0 31.25%;max-width:31.25%;}.cLXodu .uikit-col-xl-6{-webkit-flex:0 0 37.5%;-ms-flex:0 0 37.5%;flex:0 0 37.5%;max-width:37.5%;}.cLXodu .uikit-col-xl-7{-webkit-flex:0 0 43.75%;-ms-flex:0 0 43.75%;flex:0 0 43.75%;max-width:43.75%;}.cLXodu .uikit-col-xl-8{-webkit-flex:0 0 50%;-ms-flex:0 0 50%;flex:0 0 50%;max-width:50%;}.cLXodu .uikit-col-xl-9{-webkit-flex:0 0 56.25%;-ms-flex:0 0 56.25%;flex:0 0 56.25%;max-width:56.25%;}.cLXodu .uikit-col-xl-10{-webkit-flex:0 0 62.5%;-ms-flex:0 0 62.5%;flex:0 0 62.5%;max-width:62.5%;}.cLXodu .uikit-col-xl-11{-webkit-flex:0 0 68.75%;-ms-flex:0 0 68.75%;flex:0 0 68.75%;max-width:68.75%;}.cLXodu .uikit-col-xl-12{-webkit-flex:0 0 75%;-ms-flex:0 0 75%;flex:0 0 75%;max-width:75%;}.cLXodu .uikit-col-xl-13{-webkit-flex:0 0 81.25%;-ms-flex:0 0 81.25%;flex:0 0 81.25%;max-width:81.25%;}.cLXodu .uikit-col-xl-14{-webkit-flex:0 0 87.5%;-ms-flex:0 0 87.5%;flex:0 0 87.5%;max-width:87.5%;}.cLXodu .uikit-col-xl-15{-webkit-flex:0 0 93.75%;-ms-flex:0 0 93.75%;flex:0 0 93.75%;max-width:93.75%;}.cLXodu .uikit-col-xl-16{-webkit-flex:0 0 100%;-ms-flex:0 0 100%;flex:0 0 100%;max-width:100%;}.cLXodu .uikit-order-xl-first{-webkit-order:-1;-ms-flex-order:-1;order:-1;}.cLXodu .uikit-order-xl-last{-webkit-order:17;-ms-flex-order:17;order:17;}.cLXodu .uikit-order-xl-0{-webkit-order:0;-ms-flex-order:0;order:0;}.cLXodu .uikit-order-xl-1{-webkit-order:1;-ms-flex-order:1;order:1;}.cLXodu .uikit-order-xl-2{-webkit-order:2;-ms-flex-order:2;order:2;}.cLXodu .uikit-order-xl-3{-webkit-order:3;-ms-flex-order:3;order:3;}.cLXodu .uikit-order-xl-4{-webkit-order:4;-ms-flex-order:4;order:4;}.cLXodu .uikit-order-xl-5{-webkit-order:5;-ms-flex-order:5;order:5;}.cLXodu .uikit-order-xl-6{-webkit-order:6;-ms-flex-order:6;order:6;}.cLXodu .uikit-order-xl-7{-webkit-order:7;-ms-flex-order:7;order:7;}.cLXodu .uikit-order-xl-8{-webkit-order:8;-ms-flex-order:8;order:8;}.cLXodu .uikit-order-xl-9{-webkit-order:9;-ms-flex-order:9;order:9;}.cLXodu .uikit-order-xl-10{-webkit-order:10;-ms-flex-order:10;order:10;}.cLXodu .uikit-order-xl-11{-webkit-order:11;-ms-flex-order:11;order:11;}.cLXodu .uikit-order-xl-12{-webkit-order:12;-ms-flex-order:12;order:12;}.cLXodu .uikit-order-xl-13{-webkit-order:13;-ms-flex-order:13;order:13;}.cLXodu .uikit-order-xl-14{-webkit-order:14;-ms-flex-order:14;order:14;}.cLXodu .uikit-order-xl-15{-webkit-order:15;-ms-flex-order:15;order:15;}.cLXodu .uikit-order-xl-16{-webkit-order:16;-ms-flex-order:16;order:16;}.cLXodu .uikit-offset-xl-0{margin-left:0;}.cLXodu .uikit-offset-xl-1{margin-left:6.25%;}.cLXodu .uikit-offset-xl-2{margin-left:12.5 ...
# .cLXodu .flex-row{-webkit-flex-direction:row !important;-ms-flex-direction:row !important;flex-direction:row !important;}/*!sc*/
# .cLXodu .flex-column{-webkit-flex-direction:column !important;-ms-flex-direction:column !important;flex-direction:column !important;}/*!sc*/
# .cLXodu .flex-row-reverse{-webkit-flex-direction:row-reverse !important;-ms-flex-direction:row-reverse !important;flex-direction:row-reverse !important;}/*!sc*/
# .cLXodu .flex-column-reverse{-webkit-flex-direction:column-reverse !important;-ms-flex-direction:column-reverse !important;flex-direction:column-reverse !important;}/*!sc*/
# .cLXodu .flex-wrap{-webkit-flex-wrap:wrap !important;-ms-flex-wrap:wrap !important;flex-wrap:wrap !important;}/*!sc*/
# .cLXodu .flex-nowrap{-webkit-flex-wrap:nowrap !important;-ms-flex-wrap:nowrap !important;flex-wrap:nowrap !important;}/*!sc*/
# .cLXodu .flex-wrap-reverse{-webkit-flex-wrap:wrap-reverse !important;-ms-flex-wrap:wrap-reverse !important;flex-wrap:wrap-reverse !important;}/*!sc*/
# .cLXodu .flex-fill{-webkit-flex:1 1 auto !important;-ms-flex:1 1 auto !important;flex:1 1 auto !important;}/*!sc*/
# .cLXodu .flex-grow-0{-webkit-box-flex:0 !important;-webkit-flex-grow:0 !important;-ms-flex-positive:0 !important;flex-grow:0 !important;}/*!sc*/
# .cLXodu .flex-grow-1{-webkit-box-flex:1 !important;-webkit-flex-grow:1 !important;-ms-flex-positive:1 !important;flex-grow:1 !important;}/*!sc*/
# .cLXodu .flex-shrink-0{-webkit-flex-shrink:0 !important;-ms-flex-negative:0 !important;flex-shrink:0 !important;}/*!sc*/
# .cLXodu .flex-shrink-1{-webkit-flex-shrink:1 !important;-ms-flex-negative:1 !important;flex-shrink:1 !important;}/*!sc*/
# .cLXodu .justify-content-start{-webkit-box-pack:start !important;-webkit-justify-content:flex-start !important;-ms-flex-pack:start !important;justify-content:flex-start !important;}/*!sc*/
# .cLXodu .justify-content-end{-webkit-box-pack:end !important;-webkit-justify-content:flex-end !important;-ms-flex-pack:end !important;justify-content:flex-end !important;}/*!sc*/
# .cLXodu .justify-content-center{-webkit-box-pack:center !important;-webkit-justify-content:center !important;-ms-flex-pack:center !important;justify-content:center !important;}/*!sc*/
# .cLXodu .justify-content-between{-webkit-box-pack:justify !important;-webkit-justify-content:space-between !important;-ms-flex-pack:justify !important;justify-content:space-between !important;}/*!sc*/
# .cLXodu .justify-content-around{-webkit-box-pack:space-around !important;-webkit-justify-content:space-around !important;-ms-flex-pack:space-around !important;justify-content:space-around !important;}/*!sc*/
# .cLXodu .align-items-start{-webkit-align-items:flex-start !important;-webkit-box-align:flex-start !important;-ms-flex-align:flex-start !important;align-items:flex-start !important;}/*!sc*/
# .cLXodu .align-items-end{-webkit-align-items:flex-end !important;-webkit-box-align:flex-end !important;-ms-flex-align:flex-end !important;align-items:flex-end !important;}/*!sc*/
# .cLXodu .align-items-center{-webkit-align-items:center !important;-webkit-box-align:center !important;-ms-flex-align:center !important;align-items:center !important;}/*!sc*/
# .cLXodu .align-items-baseline{-webkit-align-items:baseline !important;-webkit-box-align:baseline !important;-ms-flex-align:baseline !important;align-items:baseline !important;}/*!sc*/
# .cLXodu .align-items-stretch{-webkit-align-items:stretch !important;-webkit-box-align:stretch !important;-ms-flex-align:stretch !important;align-items:stretch !important;}/*!sc*/
# .cLXodu .align-content-start{-webkit-align-content:flex-start !important;-ms-flex-line-pack:start !important;align-content:flex-start !important;}/*!sc*/
# .cLXodu .align-content-end{-webkit-align-content:flex-end !important;-ms-flex-line-pack:end !important;align-content:flex-end !important;}/*!sc*/
# .cLXodu .align-content-center{-webkit-align-content:center !important;-ms-flex-line-pack:center !important;align-content:center !important;}/*!sc*/
# ...
#            </p>
#            <h3>
#             What Is an ICO?
#            </h3>
#            <p>
#             ICO stands for initial coin offering. Many of the smaller projects in the crypto space — and a few of the largest ones — raised money from private investors around the world in the crypto equivalent of a crowdfunding campaign. Investors would send funds — usually in the form of Bitcoin — to the project and receive coin or tokens in return.
#             <br/>
#             Most ICOs happened in 2017 and early 2018 and used
#             <a href="https://coinmarketcap.com/currencies/ethereum/" target="_blank">
#              Ethereum
#             </a>
#             as a platform of operation via the ERC-20 standard. In 2018, the United States Securities and Exchange Commission (SEC) clarified their rules relating to fundraising for assets, which made it much harder for new cryptocurrency projects to issue their own tokens in this way. Since the appearance of the SEC guidance and the organization’s heightened interest in regulating ICOs for U.S. citizens, the number of ICOs has been reduced substantially.
#            </p>
#            <h3>
#             What Is a Stablecoin?
#            </h3>
#            <p>
#             Price volatility has long been one of the features of the cryptocurrency market. When asset prices move quickly in either direction and the market itself is relatively thin, it can sometimes be difficult to conduct transactions as might be needed. To overcome this problem, a new type of cryptocurrency tied in value to existing currencies — ranging from the U.S. dollar, other fiats or even other cryptocurrencies — arose. These new cryptocurrency are known as stablecoins, and they can be used for a multitude of purposes due to their stability.
#            </p>
#            <h3 id="what-are-in-game-tokens-">
#             What Are In-game Tokens?
#            </h3>
#            <p>
#             <a href="https://coinmarketcap.com/alexandria/glossary/play2earn-play-to-earn">
#              Play-to-earn
#             </a>
#             (P2E) games, also known as
#             <a href="https://coinmarketcap.com/alexandria/glossary/gamefi">
#              GameFi
#             </a>
#             , has emerged as an extremely popular category in the crypto space. It combines
#             <a href="https://coinmarketcap.com/alexandria/glossary/non-fungible-token">
#              non-fungible tokens
#             </a>
#             (NFT), in-game crypto tokens,
#             <a href="https://coinmarketcap.com/alexandria/glossary/defi">
#              decentralized finance
#             </a>
#             (DeFi) elements and sometimes even metaverse applications. Players have an opportunity to generate revenue by giving their time (and sometimes capital) and playing these games.
#            </p>
#            <p>
#             One of the biggest winners is
#             <a href="https://coinmarketcap.com/currencies/axie-infinity/">
#              Axie Infinity
#             </a>
#             — a Pokémon-inspired game where players collect Axies (NFTs of digital pets), breed and battle them against other players to earn Smooth Love Potion (SLP) — the in-game reward token. This game was extremely popular in developing countries like The Philippines, due to the decent income they can earn. Players in the Philippines can check the price of
#             <a href="https://coinmarketcap.com/currencies/smooth-love-potion/slp/php/">
#              SLP to PHP today
#             </a>
#             directly on CoinMarketCap.
#            </p>
#            <h2>
#             Which Is the Best Cryptocurrency to Invest in?
#            </h2>
#            <p>
#             CoinMarketCap does not offer financial or investment advice about which cryptocurrency, token or asset does or does not make a good investment, nor do we offer advice about the timing of purchases or sales. We are strictly a data company.
#             <br/>
#             Please remember that the prices, yields and values of financial assets change. This means that any capital you may invest is at risk. We recommend seeking the advice of a professional investment advisor for guidance related to your personal circumstances.
#            </p>
#            <h3>
#             If You Are Investing in Cryptocurrency — CoinMarketCap.com Is for You
#            </h3>
#            <p>
#             The data at CoinMarketCap updates throughout the day, which means that it is possible to check in on the value of your investments and assets at any time and from anywhere in the world. We look forward to seeing you regularly!
#            </p>
#           </div>
#           <span>
#           </span>
#          </div>
#         </div>
#        </div>
#        <div id="kevel-ads-loader">
#        </div>
#        <div id="themis-loader">
#        </div>
#       </div>
#      </div>
#     </div>
#     <section data-hydration-on-demand="true">
#      <div class="sc-1prm8qw-0 kLinMv">
#       <div class="sc-1prm8qw-0 fIjNMv grid" display="flex">
#        <div class="sc-1prm8qw-0 gRKkUT">
#         <h2 class="sc-1m04yzc-0 dqEXvD" color="text" data-sensors-click="true" font-size="24px,32px">
#          <span style="font-weight:300">
#           Be the first to know about
#          </span>
#          <div class="sc-1prm8qw-0 eyImcC" display="block,,inline">
#           crypto news every day
#          </div>
#         </h2>
#         <p class="sc-14rfo7b-0 cbhFMn" color="lights.0" data-sensors-click="true" font-size="1,2">
#          Get crypto analysis, news and updates right to your inbox! Sign up here so you don't miss a single newsletter.
#         </p>
#         <div class="sc-1prm8qw-0 etZTIR" display="block,inline-block">
#          <button class="sc-1ebmiy2-0 cRGvtw piv2lb-0 khvEXx newsletter-btn" data-sensors-click="true" type="submit">
#           Subscribe now
#          </button>
#         </div>
#        </div>
#        <img loading="lazy" src="https://s2.coinmarketcap.com/static/cloud/img/newsletter_bg_light.svg?_=e77707c"/>
#       </div>
#      </div>
#     </section>
#     <section data-hydration-on-demand="true">
#      <footer class="kyvxqd-0 kCHGDb">
#       <div class="kyvxqd-1 hsMxzm">
#        <div class="kyvxqd-2 iDSvkB">
#         <div class="sc-1m985c2-0 hiaHlZ cmc-logo">
#         </div>
#        </div>
#        <div class="kyvxqd-3 gaVFic">
#         <div class="footer-row">
#          <div class="kyvxqd-6 htAqTu">
#           <span>
#            Products
#           </span>
#           <ul>
#            <li>
#             <a href="https://blockchain.coinmarketcap.com/?utm_source=coinmarketcap&amp;utm_content=footer" rel="noopener" target="_blank">
#              Blockchain Explorer
#             </a>
#            </li>
#            <li>
#             <a href="https://coinmarketcap.com/api/" rel="noopener" target="_blank">
#              Crypto API
#             </a>
#            </li>
#            <li>
#             <a href="https://coinmarketcap.com/indices/" rel="noopener" target="_blank">
#              Crypto Indices
#             </a>
#            </li>
#            <li>
#             <a href="https://jobs.coinmarketcap.com/" target="_blank">
#              Jobs Board
#             </a>
#            </li>
#            <li>
#             <a class="cmc-link" href="/sitemap/cryptocurrencies/" rel="noopener" target="_blank">
#              Sitemap
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="kyvxqd-6 htAqTu">
#           <span>
#            Company
#           </span>
#           <ul>
#            <li>
#             <a class="cmc-link" href="/about/" target="_blank">
#              About us
#             </a>
#            </li>
#            <li>
#             <a class="cmc-link" href="/terms/" target="_blank">
#              Terms of use
#             </a>
#            </li>
#            <li>
#             <a class="cmc-link" href="/privacy/" target="_blank">
#              Privacy Policy
#             </a>
#            </li>
#            <li>
#             <a class="cmc-link" href="https://support.coinmarketcap.com/hc/en-us/articles/4412939497755" target="_blank">
#              Community Rules
#             </a>
#            </li>
#            <li>
#             <a class="cmc-link" href="/disclaimer/" target="_blank">
#              Disclaimer
#             </a>
#            </li>
#            <li>
#             <a class="cmc-link" href="/methodology/" target="_blank">
#              Methodology
#             </a>
#            </li>
#            <li>
#             <a href="/jobs" rel="noopener" target="_blank">
#              Careers
#             </a>
#             <span class="tips">
#              We’re hiring!
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="footer-row">
#          <div class="kyvxqd-6 htAqTu">
#           <span>
#            Support
#           </span>
#           <ul>
#            <li>
#             <a href="/request/" rel="noopener" target="_blank">
#              Request Form
#             </a>
#            </li>
#            <li>
#             <a href="/request/" target="_blank">
#              Contact Support
#             </a>
#            </li>
#            <li>
#             <a class="cmc-link" href="/faq/" target="_blank">
#              FAQ
#             </a>
#            </li>
#            <li>
#             <a href="https://coinmarketcap.com/alexandria/glossary" rel="noopener" target="_blank">
#              Glossary
#             </a>
#            </li>
#            <li>
#             <a href="https://coinmarketcap.com/advertising" rel="noopener" target="_blank">
#              Advertising
#             </a>
#            </li>
#           </ul>
#          </div>
#          <div class="kyvxqd-6 htAqTu">
#           <span>
#            Socials
#           </span>
#           <ul>
#            <li>
#             <a href="https://www.facebook.com/CoinMarketCap" rel="noopener" target="_blank">
#              Facebook
#             </a>
#            </li>
#            <li>
#             <a href="https://twitter.com/CoinMarketCap" rel="noopener" target="_blank">
#              Twitter
#             </a>
#            </li>
#            <li>
#             <a href="https://t.me/CoinMarketCapAnnouncements" rel="noopener" target="_blank">
#              Telegram
#             </a>
#            </li>
#            <li>
#             <a href="https://www.instagram.com/coinmarketcap/" rel="noopener" target="_blank">
#              Instagram
#             </a>
#            </li>
#            <li>
#             <a href="https://t.me/CoinMarketCapBot" rel="noopener" target="_blank">
#              Interactive Chat
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="footer-meta">
#         <div class="kyvxqd-4 HFsAq">
#          © 2022 CoinMarketCap. All rights reserved
#         </div>
#         <div class="gwabst-0 isUFDy">
#          <a class="cmc-app-store-badge cmc-link" href="https://itunes.apple.com/app/coinmarketcap/id1282107098?ls=1&amp;mt=8" target="_blank">
#           <div>
#           </div>
#          </a>
#          <a class="cmc-app-store-badge cmc-link" href="https://play.google.com/store/apps/details?id=com.coinmarketcap.android&amp;hl=en_US" target="_blank">
#           <div>
#           </div>
#          </a>
#          <a class="cmc-app-store-badge cmc-link" target="_blank">
#           <div>
#           </div>
#          </a>
#         </div>
#        </div>
#       </div>
#      </footer>
#     </section>
#     <div class="bywovg-2 itYYzK">
#      <div class="sc-1prm8qw-0 cyZVgY" style="text-align:right">
#       <div class="sc-1z13y8y-0 ccsFDY">
#        <span class="icon-Chevron-up">
#        </span>
#       </div>
#      </div>
#     </div>
#     <div class="bywovg-2 itWWjD">
#     </div>
#    </div>
#    <script>
#     (function() { true && (window.__renderTime__.pageLoadEnd = Date.now()); })()
#    </script>
#   </div>
#   <script id="__NEXT_DATA__" type="application/json">
#    {"props":{"initialI18nStore":{"en":{"common":{"Open App":"Open"},"homepage":{"homepage_seo_text":"\u003ch2\u003eToday’s Cryptocurrency Prices, Charts and Data\u003c/h2\u003e \u003cp\u003e Welcome to CoinMarketCap.com! This site was founded in May 2013 by Brandon Chez to provide up-to-date cryptocurrency prices, charts and data about the emerging cryptocurrency markets. Since then, the world of blockchain and cryptocurrency has grown exponentially and we are very proud to have grown with it. We take our data very seriously and we do not change our data to fit any narrative: we stand for accurately, timely and unbiased information. \u003c/p\u003e \u003ch2\u003eAll Your Crypto Market Data Needs in One Place\u003c/h2\u003e \u003cp\u003e Here at CoinMarketCap, we work very hard to ensure that all the relevant and \u003ca target='_blank' href='https://coinmarketcap.com/gravity/articles'\u003eup-to-date information\u003c/a\u003e about cryptocurrencies, coins and tokens can be located in one easily discoverable place. From the very first day, the goal was for the site to be the number one location online for crypto market data, and we work hard to empower our users with our unbiased and accurate information. \u003c/p\u003e \u003ch3\u003eWe Provide Live and Historic Crypto Charts for Free\u003c/h3\u003e \u003cp\u003e Each of our coin data pages has a graph that shows both the current and historic price information for the coin or token. Normally, the graph starts at the launch of the asset, but it is possible to select specific to and from dates to customize the chart to your own needs. These charts and their information are free to visitors of our website. \u003c/p\u003e \u003ch3\u003eHow Do We Calculate Our Cryptocurrency Prices?\u003c/h3\u003e \u003cp\u003e We receive updated cryptocurrency prices directly from many exchanges based on their pairs. We then convert the number to USD. A full explanation can be found \u003ca target=‘_blanket’ href='https://support.coinmarketcap.com/hc/en-us/articles/360043395752-Price-Market-Pair-Cryptoasset-'  \u003e here\u003c/a\u003e. \u003c/p\u003e \u003cp\u003e Related Links \u003cbr /\u003e New to crypto? \u003ca href='https://coinmarketcap.com/how-to-buy-bitcoin/' target=‘_blanket’\u003e Learn how to buy bitcoin today\u003c/a\u003e. \u003cbr /\u003e Ready to learn more? Visit our \u003ca href='https://coinmarketcap.com/alexandria/glossary' target=‘_blank’\u003e crypto glossary \u003c/a\u003e and \u003ca href='https://coinmarketcap.com/alexandria/' target='_blank'\u003eLearning hub\u003c/a\u003e. \u003cbr /\u003e Want to look up a transaction? \u003ca target='_blank' href='https://blockchain.coinmarketcap.com/'  \u003e Visit our blockchain explorer.\u003c/a\u003e \u003c/p\u003e \u003ch3\u003e How Do We Calculate Our Crypto Valuations?\u003c/h3\u003e \u003cp\u003e We calculate our valuations based on the total circulating supply of an asset multiplied by the currency reference price. The topic is explained in more detail \u003ca target='_blank' href='https://support.coinmarketcap.com/hc/en-us/articles/360043836811-Market-Capitalization-Cryptoasset-Aggregate-'  \u003e here\u003c/a\u003e. \u003c/p\u003e \u003ch3\u003eHow Do We Calculate the Cryptocurrency Market Cap?\u003c/h3\u003e \u003cp\u003e We calculate the total cryptocurrency market capitalization as the sum of all cryptocurrencies listed on the site. \u003c/p\u003e \u003ch2\u003eDoes CoinMarketCap.com List All Cryptocurrencies?\u003c/h2\u003e \u003cp\u003e No, we do not list all cryptocurrencies at CoinMarketCap. As a company and team, we are very aware that not all coins and projects have good intentions. While we cannot guarantee to exclude them all, we have a vetting process that each coin goes through before it is listed on the site. If we suspect that a coin or project is a scam, it does not get listed. \u003c/p\u003e \u003ch3\u003eHow Big Is the Global Coin Market?\u003c/h3\u003e \u003cp\u003e At the time of writing, we estimate that ...
#   </script>
#   <div class="gravity-recaptcha-container" style="width:100vw;height:100vh;display:none;position:fixed;left:0;top:0">
#   </div>
#  </body>
# </html>

# %%
# soup.find('script', id='__NEXT_DATA__', type='application/json')

# %%
data = soup.find('script', id='__NEXT_DATA__', type='application/json')
print(type(data))
# Out:
# <class 'bs4.element.Tag'>

# %%
coin_data = json.loads(data.contents[0])
print(coin_data.keys())
print(coin_data['props'].keys())
print(coin_data['props']['initialState'])
listings = coin_data['props']['initialState']['cryptocurrency']['listingLatest']['data']
# Out:
# dict_keys(['props', 'page', 'query', 'buildId', 'assetPrefix', 'runtimeConfig', 'isFallback', 'dynamicIds', 'customServer', 'gip', 'appGip', 'scriptLoader'])
# dict_keys(['initialI18nStore', 'initialLanguage', 'i18nServerInstance', 'pageProps', 'theme', 'getInitialStart', 'getInitialEnd', 'dehydratedState', 'initialState'])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/9r/pl8035cn4cjb59msrdwcrvhr0000gn/T/ipykernel_3453/3932026608.py in <module>
#       2 print(coin_data.keys())
#       3 print(coin_data['props'].keys())
# ----> 4 print(coin_data['props']['initialState'].keys())
#       5 listings = coin_data['props']['initialState']['cryptocurrency']['listingLatest']['data']
#
# AttributeError: 'str' object has no attribute 'keys'
